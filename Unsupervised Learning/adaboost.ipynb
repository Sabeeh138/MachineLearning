# %%
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('income.csv')
df.head()
# Out:
#    age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    income_level
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
X = df.iloc[: , 0:6]
y = df.iloc[: , 6]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
ADAB = AdaBoostClassifier(n_estimators=1000,
                          learning_rate=1)

# %%
model = ADAB.fit(X_train,y_train)
y_pred = model.predict(X_test)
print("accuracy of this is: ", accuracy_score(y_test,y_pred))
# Out:
# accuracy of this is:  0.8347834988228069

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
ADAB2= AdaBoostClassifier(n_estimators=50 , estimator=LR , learning_rate= 1)

# %%
model2 = ADAB2.fit(X_train,y_train)
y_pred2 = model.predict(X_test)

# %%
print("accuracy of this is: ", accuracy_score(y_test,y_pred2))
# Out:
# accuracy of this is:  0.8347834988228069
